# %%
# !pip3 install yfinance
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import yfinance as yf
import pandas as pd

# %%
tesla_data = yf.download('TSLA', start='2020-01-01', end='2024-02-15')
gamestop_data = yf.download('GME', start='2020-01-01', end='2024-02-15')

print(tesla_data.head())
print(gamestop_data.head())
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500
# Price        Close    High     Low    Open    Volume
# Ticker         GME     GME     GME     GME       GME
# Date
# 2020-01-02  1.5775  1.6175  1.5175  1.5350  17814400
# 2020-01-03  1.4700  1.5625  1.4600  1.5525  14175600
# 2020-01-06  1.4625  1.4775  1.4000  1.4500  13579200
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Définir l’URL de la page Yahoo Finance (Tesla)
url_tesla = "https://finance.yahoo.com/quote/TSLA/financials"

# Faire une requête GET pour récupérer la page
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url_tesla, headers=headers)

# Vérifier si la requête a réussi
if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")
    print(soup.prettify())  # Affiche le HTML de la page pour analyser
else:
    print("Erreur lors de la récupération de la page :", response.status_code)
# Out:
# <!DOCTYPE html>
# <html class="desktop neo-green dock-upscale" data-color-scheme="light" lang="en-US" theme="light">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="guce.yahoo.com" name="oath:guce:consent-host"/>
#   <link crossorigin="anonymous" href="//s.yimg.com" rel="preconnect"/>
#   <link href="//geo.yahoo.com" rel="preconnect">
#    <link href="//query1.finance.yahoo.com" rel="preconnect"/>
#    <link href="//query2.finance.yahoo.com" rel="preconnect"/>
#    <link href="//consent.cmp.oath.com" rel="preconnect"/>
#    <link as="worker" href="/__rapidworker-1.2.js" rel="preload"/>
#    <link href="https://s.yimg.com/uc/finance/webcore/js/_staticFinProtobuf.4b1559b8e4645fd93a12.js" rel="preconnect"/>
#    <link href="https://cdn.jsdelivr.net/npm/protobufjs@7.1.2/dist/minimal/protobuf.min.js" rel="preconnect"/>
#    <script>
#     window.finNeoPageStart = Date.now();
#    </script>
#    <script>
# ...

# %%
import yfinance as yf

# Download Tesla and GameStop information
tesla = yf.Ticker("TSLA")
gamestop = yf.Ticker("GME")

# Extract revenue
tesla_revenue = tesla.financials.loc["Total Revenue"]
gamestop_revenue = gamestop.financials.loc["Total Revenue"]

# View revenue
print("Revenus de Tesla :")
print(tesla_revenue)

print("\nRevenus de GameStop :")
print(gamestop_revenue)
# Out:
# Revenus de Tesla :
# 2024-12-31    97690000000.0
# 2023-12-31    96773000000.0
# 2022-12-31    81462000000.0
# 2021-12-31    53823000000.0
# 2020-12-31              NaN
# Name: Total Revenue, dtype: object
#
# Revenus de GameStop :
# 2024-01-31    5272800000.0
# 2023-01-31    5927200000.0
# 2022-01-31    6010700000.0
# 2021-01-31    5089800000.0
# Name: Total Revenue, dtype: object

# %% [markdown]
# ## Question 1 - Extracting Tesla Stock Data Using yfinance - 2 Points

# %%
import yfinance as yf

# Reset the index
tesla_data_reset = tesla_data.reset_index()

# Save CSV
tesla_data_reset.to_csv("tesla_data.csv", index=False)

# %%
# Show the first 5 rows
tesla_data_reset.head()
# Out:
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  TSLA       TSLA       TSLA       TSLA       TSLA
# 0      2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 1      2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2      2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 3      2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 4      2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %% [markdown]
# ##  Question 2: Use Webscraping to Extract Tesla Revenue Data

# %%
# Display the last five rows of the tesla_revenue 
tesla_revenue_reset = tesla_revenue.reset_index()
tesla_revenue_reset.tail()
# Out:
#        index  Total Revenue
# 0 2024-12-31  97690000000.0
# 1 2023-12-31  96773000000.0
# 2 2022-12-31  81462000000.0
# 3 2021-12-31  53823000000.0
# 4 2020-12-31            NaN

# %% [markdown]
# ## Question 3: Use yfinance to Extract Stock Data

# %%
# Reset the index
gamestop_data_reset = gamestop_data.reset_index()

# Save csv
tesla_data_reset.to_csv("tesla_data.csv", index=False)

# Show the first 5 rows
gamestop_data_reset.head()
# Out:
# Price        Date   Close    High     Low    Open    Volume
# Ticker                GME     GME     GME     GME       GME
# 0      2020-01-02  1.5775  1.6175  1.5175  1.5350  17814400
# 1      2020-01-03  1.4700  1.5625  1.4600  1.5525  14175600
# 2      2020-01-06  1.4625  1.4775  1.4000  1.4500  13579200
# 3      2020-01-07  1.3800  1.4575  1.3600  1.4425  20912000
# 4      2020-01-08  1.4300  1.4625  1.3525  1.3725  22517600

# %% [markdown]
# ## Question 4: Use Webscraping to Extract GME Revenue Data

# %%
# Display the last five rows of the tesla_revenue
gamestop_revenue_reset = gamestop_data.reset_index()
gamestop_revenue_reset.tail()
# Out:
# Price        Date  Close   High    Low   Open   Volume
# Ticker               GME    GME    GME    GME      GME
# 1032   2024-02-08  14.35  14.44  13.89  14.01  1838300
# 1033   2024-02-09  14.66  15.23  14.30  14.37  3575300
# 1034   2024-02-12  14.73  15.22  14.53  14.58  2750100
# 1035   2024-02-13  14.17  14.40  13.77  14.20  3788700
# 1036   2024-02-14  14.41  14.43  14.05  14.33  2504400

# %% [markdown]
# ## Question 5: Plot Tesla Stock Graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import yfinance as yf

# %%
def make_graph(data, title):
    """
    Fonction pour tracer un graphique des prix de clôture d'une action.
    
    Paramètres :
    - data : DataFrame contenant les données boursières (ex: tesla_data)
    - title : Titre du graphique
    """
    plt.figure(figsize=(12, 6))
    plt.plot(data['Date'], data['Close'], label="Prix de Clôture", color='blue', linewidth=2)

    # Add a title and labels
    plt.title(title, fontsize=14)
    plt.xlabel("Date")
    plt.ylabel("Prix de clôture ($)")
    plt.legend()
    plt.grid()

    # View Chart
    plt.show()

# %%
# Reset the index so that the "Date" column is usable
tesla_data_reset = tesla_data.reset_index()

# Plot the Tesla stock chart
make_graph(tesla_data_reset, "Tesla stock price action (TSLA) Evolution")

# %% [markdown]
# ## Question 6: Plot GameStop Stock Graph

# %%
gamestop_data_reset = gamestop_data.reset_index()

# %%
make_graph(gamestop_data_reset, "GameStop (GME) Stock Price Evolution")
